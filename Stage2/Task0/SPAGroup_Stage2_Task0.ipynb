# %% [markdown]
# #Stage 2
# VIP CUP
# ______
# **SPA Group**
# Sajjad Jabbarzade
# Parham Soltani
# Amirtaha Aghasi
#
# ______

# %% [markdown]
# ##Libraries

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ##Preparing Data
# Importing the goat.mp4 video into the Google VM Drive

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40d1481c-8fcd-4524-ab0d-c514c862c0fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40d1481c-8fcd-4524-ab0d-c514c862c0fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##Functions

# %%
def framextractor(ok, frame, index, framelist, framedim=None, framedimout=False, plot=False):
  breakloop = 0
  if ok == True:
    framelist.append(frame)
    if framedimout == True:
      h, w, c = frame.shape
      dim = [h, w, c]
      framedim.append(dim)
    print(f"Frame {index}")
    index += 1
    if plot == True:
      plt.imshow(frame[:,:,::-1])
      plt.show()
  else:
    print("All frames have been imported")
    breakloop = 1
  return framelist, framedim, index, breakloop

# %% [markdown]
# ##Task 0

# %%
from google.colab.patches import cv2_imshow

# %%
video_input_file_name = "/content/goat.mp4"
video = cv2.VideoCapture(video_input_file_name)

# %%
fps = video.get(cv2.CAP_PROP_FPS)

# %%
print(fps)
# Out:
# 30.0

# %%
idx = 0
framelist = list()
while True:
  ok, frame = video.read()
  framelist, _, idx, breakloop = framextractor(ok, frame, idx, framelist, framedimout=False, plot=True)
  if breakloop == 1: break
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
list_of_messi_index = [10,
                       11,
                       18,
                       28,
                       29,
                       36,
                       46,
                       47,
                       55,
                       64,
                       65,
                       73,
                       82,
                       83,
                       91,
                       101,
                       102,
                       109,
                       119,
                       120,
                       127,
                       128,
                       129]

# %%
video_output_file_name = "Our Output.mp4"
width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
video_out = cv2.VideoWriter(video_output_file_name, cv2.VideoWriter_fourcc(*"XVID"), fps/3, (width, height))

# %%
for idx in list_of_messi_index:
  frameout = framelist[idx]
  video_out.write(frameout)

video.release()
video_out.release()

# %%
cv2.imwrite("Out 1.jpg", framelist[120])
cv2.imwrite("Out 2.jpg", framelist[127])
# Out:
# True
